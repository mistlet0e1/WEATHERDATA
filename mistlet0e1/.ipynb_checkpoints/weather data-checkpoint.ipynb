# %%
import pandas as pd
import numpy as np

# Read the Excel file
df = pd.read_excel("Weather_Data.xlsx")

# Display first 5 rows
print(df.head())
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C              Rel Hum_%  \
# 0  2012-01-01 00:00:00    -1.8              -3.9                     86
# 1  2012-01-01 01:00:00    -1.8              -3.7    import pandas as pd
# 2  2012-01-01 02:00:00    -1.8              -3.4     import numpy as np
# 3  2012-01-01 03:00:00    -1.5              -3.2                    NaN
# 4  2012-01-01 04:00:00    -1.5              -3.3  # Read the Excel file
#
#    Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                4            8.0     101.24                   Fog
# 1                4            8.0     101.24                   Fog
# 2                7            4.0     101.26  Freezing Drizzle,Fog
# 3                6            4.0     101.27  Freezing Drizzle,Fog
# 4                7            4.8     101.23                   Fog

# %%
# Unique Wind Speeds
print(df["Wind Speed_km/h"].unique())
# Out:
# [ 4  7  6  9 15 13 20 22 19 24 30 35 39 32 33 26 44 43 48 37 28 17 11  0
#  83 70 57 46 41 52 50 63 54  2]

# %%
# Count of Clear Weather
print(df[df["Weather"] == "Clear"].shape[0])
# Out:
# 1326

# %%
# Wind Speed = 4
print(df[df["Wind Speed_km/h"] == 4])
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C            Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9                   86
# 1     2012-01-01 01:00:00    -1.8              -3.7  import pandas as pd
# 96    2012-05-01 00:00:00    -8.8             -11.7                   79
# 101   2012-05-01 05:00:00    -7.0              -9.5                   82
# 146   2012-07-01 02:00:00    -8.1             -11.1                   79
# ...                   ...     ...               ...                  ...
# 8768      12/31/2012 8:00    -8.6             -10.3                   87
# 8769      12/31/2012 9:00    -8.1              -9.6                   89
# 8770     12/31/2012 10:00    -7.4              -8.9                   89
# 8772     12/31/2012 12:00    -5.8              -7.5                   88
# 8773     12/31/2012 13:00    -4.6              -6.6                   86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# ...

# %%
# Mean Visibility
print(df["Visibility_km"].mean())
# Out:
# 27.664446721311474

# %%
# Standard Deviation of Pressure
print(df["Press_kPa"].std())
# Out:
# 0.8440047459486483

# %%
# Records containing Snow
print(df[df["Weather"].str.contains("Snow", case=False)])
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C Rel Hum_%  \
# 41    2012-02-01 17:00:00    -2.1              -9.5        57
# 44    2012-02-01 20:00:00    -5.6             -13.4        54
# 45    2012-02-01 21:00:00    -5.8             -12.8        58
# 47    2012-02-01 23:00:00    -7.4             -14.1        59
# 48    2012-03-01 00:00:00    -9.0             -16.0        57
# ...                   ...     ...               ...       ...
# 8779     12/31/2012 19:00     0.1              -2.7        81
# 8780     12/31/2012 20:00     0.2              -2.4        83
# 8781     12/31/2012 21:00    -0.5              -1.5        93
# 8782     12/31/2012 22:00    -0.2              -1.8        89
# 8783     12/31/2012 23:00     0.0              -2.1        86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 41                 22           25.0      99.66  Snow Showers
# 44                 24           25.0     100.07  Snow Showers
# ...

# %%
# Weather = Fog
print(df[df["Weather"] == "Fog"])
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  \
# 0     2012-01-01 00:00:00    -1.8              -3.9
# 1     2012-01-01 01:00:00    -1.8              -3.7
# 4     2012-01-01 04:00:00    -1.5              -3.3
# 5     2012-01-01 05:00:00    -1.4              -3.3
# 6     2012-01-01 06:00:00    -1.5              -3.1
# ...                   ...     ...               ...
# 8716      12/29/2012 4:00   -16.0             -17.2
# 8717      12/29/2012 5:00   -14.8             -15.9
# 8718      12/29/2012 6:00   -13.8             -15.3
# 8719      12/29/2012 7:00   -14.8             -16.4
# 8722     12/29/2012 10:00   -12.0             -13.3
#
#                                     Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0                                          86                4            8.0
# 1                         import pandas as pd                4            8.0
# 4                       # Read the Excel file                7            4.8
# ...

# %%
# Mean of each numeric column grouped by Weather
print(df.groupby("Weather").mean(numeric_only=True))
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
# Weather = Clear OR Visibility > 40
print(df[(df["Weather"] == "Clear") | (df["Visibility_km"] > 40)])
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C Rel Hum_%  \
# 67    2012-03-01 19:00:00   -16.9             -24.8        50
# 106   2012-05-01 10:00:00    -6.0             -10.0        73
# 107   2012-05-01 11:00:00    -5.6             -10.2        70
# 108   2012-05-01 12:00:00    -4.7              -9.6        69
# 109   2012-05-01 13:00:00    -4.4              -9.7        66
# ...                   ...     ...               ...       ...
# 8749     12/30/2012 13:00   -12.4             -16.2        73
# 8750     12/30/2012 14:00   -11.8             -16.1        70
# 8751     12/30/2012 15:00   -11.3             -15.6        70
# 8752     12/30/2012 16:00   -11.4             -15.5        72
# 8756     12/30/2012 20:00   -13.8             -16.5        80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 67                 24           25.0     101.74          Clear
# 106                17           48.3     100.45   Mainly Clear
# ...

# %%
print(df[(df["Weather"] == "Clear") & (df["Rel Hum_%"] > 50)])
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 114   2012-05-01 18:00:00    -7.1             -14.4       56.0
# 115   2012-05-01 19:00:00    -9.2             -15.4       61.0
# 116   2012-05-01 20:00:00    -9.8             -15.7       62.0
# 117   2012-05-01 21:00:00    -9.0             -14.8       63.0
# 241   2012-11-01 01:00:00   -10.7             -17.8       56.0
# ...                   ...     ...               ...        ...
# 8646      12/26/2012 6:00   -13.4             -14.8       89.0
# 8698     12/28/2012 10:00    -6.1              -8.6       82.0
# 8713      12/29/2012 1:00   -11.9             -13.6       87.0
# 8714      12/29/2012 2:00   -11.8             -13.1       90.0
# 8756     12/30/2012 20:00   -13.8             -16.5       80.0
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 114                11           25.0     100.71   Clear
# 115                 7           25.0     100.80   Clear
# ...
